# %% [markdown]
# ### Lambda Functions are anonymous functions means that the function is without a name. As we already know def keyword is used to define a normal function in Python. Similarly, lambda keyword is used to define an anonymous function in Python.

# %%
s2 = lambda data: data.upper()
print(s2("chandan"))

# %% [markdown]
# ### Using with Condition Checking

# %%
result = lambda x: "POSITIVE" if x > 0 else "NEGATIVE" if x < 0 else "ZERO"
print(result(1))

# %%
check = lambda x: "EVEN" if x % 2 == 0 else "ODD"
print(check(3))

# %% [markdown]
# ### Using with List Comprehension

# %%
# This code creates a list of lambda functions, each multiplying its input by 10 and then executes them one by one.

li = [lambda arg=x: arg * 10 for x in range(1, 5)]

for num in li:
    print(num())

# %% [markdown]
# ### Using for Returning Multiple Results

# %%
# The lambda calculates both sum and product of two numbers and returns them as a tuple.

calc = lambda x, y: (x + y, x * y)
res = calc(3, 4)
print(res)

# %%
data = [
    {
        "id": 101,
        "title": "Post One",
        "tags": [
            "intro",
            "python"
        ],
        "author": {
            "name": "Alice",
            "role": "admin"
        }
    },
    {
        "id": 102,
        "title": "Post Two",
        "tags": [],
        "author": {
            "name": "Bob",
            "role": "editor"
        }
    }
]

# %% [markdown]
# ### Using with filter()

# %%
# The lambda is used as a filtering condition to keep only even numbers from the list.

list(filter(lambda x: x["id"] == 101, data))

# %% [markdown]
# ### Using with map()

# %%
list(map(lambda x: {"id": x["id"], "name": x["author"]["name"]}, data))

# %% [markdown]
# ![image.png](attachment:image.png)
