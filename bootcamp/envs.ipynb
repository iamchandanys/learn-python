# %%
import os

# This script prints all environment variables and their values
for key, value in os.environ.items():
    print(f"{key} = {value}")

# %%
import os

# Print a specific environment variable
print(os.environ.get("AZURE_OPENAI_API_KEY"))
